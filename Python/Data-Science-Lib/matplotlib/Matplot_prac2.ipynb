# %%
from matplotlib import pyplot as plt

# %%
fig=plt.figure()
axis=fig.add_axes([0.5,0.1,0.8,0.8])
axis.plot(x,y,'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 fig=plt.figure()
#       2 axis=fig.add_axes([0.5,0.1,0.8,0.8])
# ----> 3 axis.plot(x,y,'r')
#
# NameError: name 'x' is not defined
