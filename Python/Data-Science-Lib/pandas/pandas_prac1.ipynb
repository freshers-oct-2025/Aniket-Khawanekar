# %%
import pandas as pd

# %%
arr=[0,1,2,3,4]
s1=pd.Series(arr)
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
order=[4,5,6,3,4]
s2=pd.Series(arr,index=order)
s2
# Out:
# 4    0
# 5    1
# 6    2
# 3    3
# 4    4
# dtype: int64

# %%
import numpy as np
n=np.random.randn(5)
index=['a','b','c','d','e']
s2=pd.Series(n,index=index)
s2
# Out:
# a   -2.055478
# b    0.476253
# c    0.496559
# d    0.788325
# e   -0.712108
# dtype: float64

# %% [markdown]
# #Series Operations

# %%
a1=[0,2,3,4,5,7,9]
a2=[4,3,2,1,4,6,]

# %%
s5=pd.Series(a2)
s5
# Out:
# 0    4
# 1    3
# 2    2
# 3    1
# 4    4
# 5    6
# dtype: int64

# %%
s6=pd.Series(a1)
s6
# Out:
# 0    0
# 1    2
# 2    3
# 3    4
# 4    5
# 5    7
# 6    9
# dtype: int64

# %%
s5.add(s6)
# Out:
# 0     4.0
# 1     5.0
# 2     5.0
# 3     5.0
# 4     9.0
# 5    13.0
# 6     NaN
# dtype: float64

# %%
s5.mul(s6)
# Out:
# 0     0.0
# 1     6.0
# 2     6.0
# 3     4.0
# 4    20.0
# 5    42.0
# 6     NaN
# dtype: float64

# %%
s5.div(s6)
# Out:
# 0         inf
# 1    1.500000
# 2    0.666667
# 3    0.250000
# 4    0.800000
# 5    0.857143
# 6         NaN
# dtype: float64

# %%
s6.median()
s6.max()
s6.min
# Out:
# <bound method Series.min of 0    0
# 1    2
# 2    3
# 3    4
# 4    5
# 5    7
# 6    9
# dtype: int64>

# %% [markdown]
# #DataFrames

# %%
dates=pd.date_range('today',periods=6)
num_arr=np.random.randn(6,4)
columns=['A','B','C','D']

df1=pd.DataFrame(num_arr,index=dates,columns=columns)
df1
# Out:
#                                    A         B         C         D
# 2025-11-24 16:54:03.721583 -0.868623 -0.109469  0.021523 -1.911669
# 2025-11-25 16:54:03.721583 -1.103317 -0.087869  0.595341 -0.292174
# 2025-11-26 16:54:03.721583  0.503424 -0.489676  0.362131  1.260142
# 2025-11-27 16:54:03.721583 -1.330624 -1.175616  0.465351 -1.092474
# 2025-11-28 16:54:03.721583  0.133658 -0.207291 -0.034831 -1.555912
# 2025-11-29 16:54:03.721583  0.043869 -0.473170  0.350174  2.404289

# %%
data={
    'animal':['cat','dog','cat','snake','dog','cat','dog','snake','dog','dog'],
    'age':[2.5,3,0.5,np.nan,5,2,4.5,np.nan,7,3],
    'visits':[1,2,4,2,4,2,1,2,3,2],
    'priority':['high','low','high','high','v-low','high','low','low','v-low','high']
}
labels=['a','b','c','d','e','f','g','h','i','j']

df2=pd.DataFrame(data,index=labels)
df2
# Out:
#   animal  age  visits priority
# a    cat  2.5       1     high
# b    dog  3.0       2      low
# c    cat  0.5       4     high
# d  snake  NaN       2     high
# e    dog  5.0       4    v-low
# f    cat  2.0       2     high
# g    dog  4.5       1      low
# h  snake  NaN       2      low
# i    dog  7.0       3    v-low
# j    dog  3.0       2     high

# %%
print(df2.index)
df2.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
# Index(['animal', 'age', 'visits', 'priority'], dtype='object')

# %%
df2.values
# Out:
# array([['cat', 2.5, 1, 'high'],
#        ['dog', 3.0, 2, 'low'],
#        ['cat', 0.5, 4, 'high'],
#        ['snake', nan, 2, 'high'],
#        ['dog', 5.0, 4, 'v-low'],
#        ['cat', 2.0, 2, 'high'],
#        ['dog', 4.5, 1, 'low'],
#        ['snake', nan, 2, 'low'],
#        ['dog', 7.0, 3, 'v-low'],
#        ['dog', 3.0, 2, 'high']], dtype=object)

# %%
df2.describe()
# Out:
#             age    visits
# count  8.000000  10.00000
# mean   3.437500   2.30000
# std    2.007797   1.05935
# min    0.500000   1.00000
# 25%    2.375000   2.00000
# 50%    3.000000   2.00000
# 75%    4.625000   2.75000
# max    7.000000   4.00000

# %%
df2.T
# Out:
#              a    b     c      d      e     f    g      h      i     j
# animal     cat  dog   cat  snake    dog   cat  dog  snake    dog   dog
# age        2.5  3.0   0.5    NaN    5.0   2.0  4.5    NaN    7.0   3.0
# visits       1    2     4      2      4     2    1      2      3     2
# priority  high  low  high   high  v-low  high  low    low  v-low  high

# %%
df2.sort_values(by="age")
# Out:
#   animal  age  visits priority
# c    cat  0.5       4     high
# f    cat  2.0       2     high
# a    cat  2.5       1     high
# b    dog  3.0       2      low
# j    dog  3.0       2     high
# g    dog  4.5       1      low
# e    dog  5.0       4    v-low
# i    dog  7.0       3    v-low
# d  snake  NaN       2     high
# h  snake  NaN       2      low

# %%
df2[1:3]
# Out:
#   animal  age  visits priority
# b    dog  3.0       2      low
# c    cat  0.5       4     high

# %%
df2.sort_values(by="age")[5:9]
# Out:
#   animal  age  visits priority
# g    dog  4.5       1      low
# e    dog  5.0       4    v-low
# i    dog  7.0       3    v-low
# d  snake  NaN       2     high

# %%
df2[['age','visits']]
# Out:
#    age  visits
# a  2.5       1
# b  3.0       2
# c  0.5       4
# d  NaN       2
# e  5.0       4
# f  2.0       2
# g  4.5       1
# h  NaN       2
# i  7.0       3
# j  3.0       2

# %%
df3=df2.copy()

# %%
df3.isnull()
# Out:
#    animal    age  visits  priority
# a   False  False   False     False
# b   False  False   False     False
# c   False  False   False     False
# d   False   True   False     False
# e   False  False   False     False
# f   False  False   False     False
# g   False  False   False     False
# h   False   True   False     False
# i   False  False   False     False
# j   False  False   False     False

# %%
df3.loc['f','age']=19
df3
# Out:
#   animal   age  visits priority
# a    cat   2.5       1     high
# b    dog   3.0       2      low
# c    cat   0.5       4     high
# d  snake   NaN       2     high
# e    dog   5.0       4    v-low
# f    cat  19.0       2     high
# g    dog   4.5       1      low
# h  snake   NaN       2      low
# i    dog   7.0       3    v-low
# j    dog   3.0       2     high

# %%
df2[['age']].mean()
# Out:
# age    3.4375
# dtype: float64

# %%
df3[['age','visits']].mean()
# Out:
# age       5.5625
# visits    2.3000
# dtype: float64

# %%
df3[['age','visits']].max()
# Out:
# age       19.0
# visits     4.0
# dtype: float64

# %%
df3[['age','visits']].sum()
# Out:
# age       44.5
# visits    23.0
# dtype: float64

# %%
df3.sum()
# Out:
# animal           catdogcatsnakedogcatdogsnakedogdog
# age                                            44.5
# visits                                           23
# priority    highlowhighhighv-lowhighlowlowv-lowhigh
# dtype: object

# %%
df4=df3.copy()
meanage=df4['age'].mean()
df4['age'].fillna(meanage)
print(df4)
# Out:
#   animal   age  visits priority
# a    cat   2.5       1     high
# b    dog   3.0       2      low
# c    cat   0.5       4     high
# d  snake   NaN       2     high
# e    dog   5.0       4    v-low
# f    cat  19.0       2     high
# g    dog   4.5       1      low
# h  snake   NaN       2      low
# i    dog   7.0       3    v-low
# j    dog   3.0       2     high

# %%
df2
# Out:
#   animal  age  visits priority
# a    cat  2.5       1     high
# b    dog  3.0       2      low
# c    cat  0.5       4     high
# d  snake  NaN       2     high
# e    dog  5.0       4    v-low
# f    cat  2.0       2     high
# g    dog  4.5       1      low
# h  snake  NaN       2      low
# i    dog  7.0       3    v-low
# j    dog  3.0       2     high

# %%
df5=df2.copy()
df5.dropna(how='any')
# Out:
#   animal  age  visits priority
# a    cat  2.5       1     high
# b    dog  3.0       2      low
# c    cat  0.5       4     high
# e    dog  5.0       4    v-low
# f    cat  2.0       2     high
# g    dog  4.5       1      low
# i    dog  7.0       3    v-low
# j    dog  3.0       2     high

# %%
import numpy as np 
# %matplotlib inline

ts=pd.Series(np.random.randn(50),index=pd.date_range('today',periods=50))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(50,4),index=ts.index,columns=['A','B','X','Y'])
df=df.cumsum()
df.plot()
# Out:
# <Axes: >
